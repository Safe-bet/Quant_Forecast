# %%
#!/usr/bin/env python
try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

import certifi
import json

def get_jsonparsed_data(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

url = ("https://financialmodelingprep.com/api/v3/search?query=AA&apikey=qVXvjPhg98aEFqlvCHfmX1lBWWoXbYF4")
print(get_jsonparsed_data(url))
# Out:
# <ipython-input-24-1749cd9225f2>:13: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-24-1749cd9225f2> in <cell line: 18>()
#      16
#      17 url = ("https://financialmodelingprep.com/api/v3/search?query=AA&apikey=qVXvjPhg98aEFqlvCHfmX1lBWWoXbYF4")
# ---> 18 print(get_jsonparsed_data(url))
#
# <ipython-input-24-1749cd9225f2> in get_jsonparsed_data(url)
#      11
#      12 def get_jsonparsed_data(url):
# ---> 13     response = urlopen(url, cafile=certifi.where())
#      14     data = response.read().decode("utf-8")
#      15     return json.loads(data)
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
type(url)
# Out:
# str

# %% [markdown]
# Code to search Ticker

# %%
url = ("https://financialmodelingprep.com/api/v3/search-ticker?query=META&exchange=NASDAQ&apikey=qVXvjPhg98aEFqlvCHfmX1lBWWoXbYF4")
print(get_jsonparsed_data(url))
# Out:
# <ipython-input-20-1749cd9225f2>:13: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-22-330fa61ac1b2> in <cell line: 2>()
#       1 url = ("https://financialmodelingprep.com/api/v3/search-ticker?query=META&exchange=NASDAQ&apikey=qVXvjPhg98aEFqlvCHfmX1lBWWoXbYF4")
# ----> 2 print(get_jsonparsed_data(url))
#
# <ipython-input-20-1749cd9225f2> in get_jsonparsed_data(url)
#      11
#      12 def get_jsonparsed_data(url):
# ---> 13     response = urlopen(url, cafile=certifi.where())
#      14     data = response.read().decode("utf-8")
#      15     return json.loads(data)
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests

# %% [markdown]
# Code to search Name of the Company

# %%
url = ("https://financialmodelingprep.com/api/v3/search-name?query=META&limit=1&exchange=NASDAQ&apikey=qVXvjPhg98aEFqlvCHfmX1lBWWoXbYF4")
print(get_jsonparsed_data(url))

# %%
url = ("https://financialmodelingprep.com/api/v3/search-name?query=Meta&limit=1&exchange=NASDAQ&apikey=qVXvjPhg98aEFqlvCHfmX1lBWWoXbYF4")
print(get_jsonparsed_data(url))

# %% [markdown]
# Searching for a particular stock ticker

# %%
url = ("https://financialmodelingprep.com/api/v3/profile/AAPL?apikey=qVXvjPhg98aEFqlvCHfmX1lBWWoXbYF4")
print(get_jsonparsed_data(url))

# %% [markdown]
# FMP's Income Statement API provides access to real-time income statement data for a wide range of companies, including public companies, private companies, and ETFs. This data can be used to track a company's profitability over time, to compare a company to its competitors, and to identify trends in a company's business.

# %%
inst = get_jsonparsed_data(f"https://financialmodelingprep.com/api/v3/income-statement/{'AAPL'}?period=annual&apikey=qVXvjPhg98aEFqlvCHfmX1lBWWoXbYF4")

# %%
inst

# %%
import pandas as pd
df1 = pd.DataFrame(inst)
df1 = df1.set_index(['date'])
df1

# %%
df1.isnull().sum()

# %% [markdown]
# preparing the dataset for annual prediction of a stock

# %%
import pandas as pd
import requests

# List of NASDAQ 100 companies (only symbols are needed for API requests)
nasdaq_100_companies = [
    "AAPL", "MSFT", "AMZN", "NVDA", "GOOGL", "META", "TSLA", "AVGO", "PEP", "COST",
    "ADBE", "CSCO", "TXN", "CMCSA", "NFLX", "AMD", "INTC", "CHTR", "QCOM", "PYPL",
    "SBUX", "ISRG", "BKNG", "GILD", "REGN", "ADI", "TEAM", "DOCU", "ZM", "AMGN",
    "ILMN", "CSX", "MAR", "CTAS", "DXCM", "WDAY", "MNST", "NXPI", "LULU", "EBAY",
    "ORLY", "MELI", "KDP", "ROST", "MCHP", "PCAR", "PANW", "CDNS", "VRTX", "LRCX",
    "KLAC", "ADP", "BIIB", "AMAT", "SNPS", "XLNX", "IDXX", "SPLK", "ALGN", "HOLX",
    "CDNS", "ILMN", "ADSK", "SGEN", "ZBRA", "NTES", "DOCU", "FTNT", "VRSK", "TMUS",
    "CHTR", "CTSH", "XEL", "LBTYA", "TTWO", "EXPE", "EA", "LUMN", "SWKS", "MTCH",
    "MRNA", "OKTA", "ZM", "CMG", "BMRN", "SNOW", "ODFL", "DDOG", "TTD", "PDD",
    "CSGP", "MRVL", "ZS", "CRWD", "EPAM", "PAYX", "FAST", "CERN", "SIRI", "ATUS",
    "NTAP"
]

# Define a function to get JSON data from the API
def get_jsonparsed_data(url):
    response = requests.get(url)
    return response.json()

# Initialize an empty DataFrame
df = pd.DataFrame()

# API key for Financial Modeling Prep
api_key = "qVXvjPhg98aEFqlvCHfmX1lBWWoXbYF4"

# Fetch data for each company and concatenate into the main DataFrame
for symbol in nasdaq_100_companies:
    url = f"https://financialmodelingprep.com/api/v3/balance-sheet-statement/{symbol}?period=annual&apikey={api_key}"
    try:
        data = get_jsonparsed_data(url)
        df_temp = pd.DataFrame(data)
        df_temp['symbol'] = symbol
        df = pd.concat([df, df_temp], ignore_index=True)
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")

# Set the 'date' column as the index
df.set_index('date', inplace=True)

# Display the DataFrame
print(df)
# Out:
# Error fetching data for MNST: If using all scalar values, you must pass an index
# Error fetching data for NXPI: If using all scalar values, you must pass an index
# Error fetching data for LULU: If using all scalar values, you must pass an index
# Error fetching data for EBAY: If using all scalar values, you must pass an index
# Error fetching data for ORLY: If using all scalar values, you must pass an index
# Error fetching data for MELI: If using all scalar values, you must pass an index
# Error fetching data for KDP: If using all scalar values, you must pass an index
# Error fetching data for ROST: If using all scalar values, you must pass an index
# Error fetching data for MCHP: If using all scalar values, you must pass an index
# Error fetching data for PCAR: If using all scalar values, you must pass an index
# Error fetching data for PANW: If using all scalar values, you must pass an index
# Error fetching data for CDNS: If using all scalar values, you must pass an index
# Error fetching data for VRTX: If using all scalar values, you must pass an index
# Error fetching data for LRCX: If using all scalar values, you must pass an index
# Error fetching data for KLAC: If using all scalar values, you must pass an index
# Error fetching data for ADP: If using all scalar values, you must pass an index
# Error fetching data for BIIB: If using all scalar values, you must pass an index
# Error fetching data for AMAT: If using all scalar values, you must pass an index
# Error fetching data for SNPS: If using all scalar values, you must pass an index
# Error fetching data for XLNX: If using all scalar values, you must pass an index
# Error fetching data for IDXX: If using all scalar values, you must pass an index
# Error fetching data for SPLK: If using all scalar values, you must pass an index
# Error fetching data for ALGN: If using all scalar values, you must pass an index
# Error fetching data for HOLX: If using all scalar values, you must pass an index
# Error fetching data for CDNS: If using all scalar values, you must pass an index
# Error fetching data for ILMN: If using all scalar values, you must pass an index
# Error fetching data for ADSK: If using all scalar values, you must pass an index
# Error fetching data for SGEN: If using all scalar values, you must pass an index
# Error fetching data for ZBRA: If using all scalar values, you must pass an index
# Error fetching data for NTES: If using all scalar values, you must pass an index
# Error fetching data for DOCU: If using all scalar values, you must pass an index
# Error fetching data for FTNT: If using all scalar values, you must pass an index
# Error fetching data for VRSK: If using all scalar values, you must pass an index
# Error fetching data for TMUS: If using all scalar values, you must pass an index
# Error fetching data for CHTR: If using all scalar values, you must pass an index
# Error fetching data for CTSH: If using all scalar values, you must pass an index
# Error fetching data for XEL: If using all scalar values, you must pass an index
# Error fetching data for LBTYA: If using all scalar values, you must pass an index
# Error fetching data for TTWO: If using all scalar values, you must pass an index
# Error fetching data for EXPE: If using all scalar values, you must pass an index
# Error fetching data for EA: If using all scalar values, you must pass an index
# Error fetching data for LUMN: If using all scalar values, you must pass an index
# Error fetching data for SWKS: If using all scalar values, you must pass an index
# Error fetching data for MTCH: If using all scalar values, you must pass an index
# Error fetching data for MRNA: If using all scalar values, you must pass an index
# Error fetching data for OKTA: If using all scalar values, you must pass an index
# Error fetching data for ZM: If using all scalar values, you must pass an index
# Error fetching data for CMG: If using all scalar values, you must pass an index
# Error fetching data for BMRN: If using all scalar values, you must pass an index
# Error fetching data for SNOW: If using all scalar values, you must pass an index
# Error fetching data for ODFL: If using all scalar values, you must pass an index
# Error fetching data for DDOG: If using all scalar values, you must pass an index
# Error fetching data for TTD: If using all scalar values, you must pass an index
# Error fetching data for PDD: If using all scalar values, you must pass an index
# Error fetching data for CSGP: If using all scalar values, you must pass an index
# Error fetching data for MRVL: If using all scalar values, you must pass an index
# Error fetching data for ZS: If using all scalar values, you must pass an index
# Error fetching data for CRWD: If using all scalar values, you must pass an index
# Error fetching data for EPAM: If using all scalar values, you must pass an index
# Error fetching data for PAYX: If using all scalar values, you must pass an index
# Error fetching data for FAST: If using all scalar values, you must pass an index
# Error fetching data for CERN: If using all scalar values, you must pass an index
# Error fetching data for SIRI: If using all scalar values, you must pass an index
# Error fetching data for ATUS: If using all scalar values, you must pass an index
# Error fetching data for NTAP: If using all scalar values, you must pass an index
#            symbol reportedCurrency         cik fillingDate  \
# date
# 2023-09-30   AAPL              USD  0000320193  2023-11-03
# 2022-09-24   AAPL              USD  0000320193  2022-10-28
# 2021-09-25   AAPL              USD  0000320193  2021-10-29
# 2020-09-26   AAPL              USD  0000320193  2020-10-30
# 2019-09-28   AAPL              USD  0000320193  2019-10-31
# ...           ...              ...         ...         ...
# 2024-01-31   WDAY              USD  0001327811  2024-03-08
# 2023-01-31   WDAY              USD  0001327811  2023-02-27
# 2022-01-31   WDAY              USD  0001327811  2022-02-28
# 2021-01-31   WDAY              USD  0001327811  2021-03-02
# 2020-01-31   WDAY              USD  0001327811  2020-03-03
#
#                    acceptedDate calendarYear period  cashAndCashEquivalents  \
# date
# 2023-09-30  2023-11-02 18:08:27         2023     FY             29965000000
# 2022-09-24  2022-10-27 18:01:14         2022     FY             23646000000
# 2021-09-25  2021-10-28 18:04:28         2021     FY             34940000000
# 2020-09-26  https://www.sec.gov/Archives/edgar/data/320193...
# 2019-09-28  https://www.sec.gov/Archives/edgar/data/320193...
# ...                                                       ...
# 2024-01-31  https://www.sec.gov/Archives/edgar/data/132781...
# 2023-01-31  https://www.sec.gov/Archives/edgar/data/132781...
# 2022-01-31  https://www.sec.gov/Archives/edgar/data/132781...
# 2021-01-31  https://www.sec.gov/Archives/edgar/data/132781...
# 2020-01-31  https://www.sec.gov/Archives/edgar/data/132781...
#
# [180 rows x 53 columns]

# %%
df.columns
# Out:
# Index(['symbol', 'reportedCurrency', 'cik', 'fillingDate', 'acceptedDate',
#        'calendarYear', 'period', 'cashAndCashEquivalents',
#        'shortTermInvestments', 'cashAndShortTermInvestments', 'netReceivables',
#        'inventory', 'otherCurrentAssets', 'totalCurrentAssets',
#        'propertyPlantEquipmentNet', 'goodwill', 'intangibleAssets',
#        'goodwillAndIntangibleAssets', 'longTermInvestments', 'taxAssets',
#        'otherNonCurrentAssets', 'totalNonCurrentAssets', 'otherAssets',
#        'totalAssets', 'accountPayables', 'shortTermDebt', 'taxPayables',
#        'deferredRevenue', 'otherCurrentLiabilities', 'totalCurrentLiabilities',
#        'longTermDebt', 'deferredRevenueNonCurrent',
#        'deferredTaxLiabilitiesNonCurrent', 'otherNonCurrentLiabilities',
#        'totalNonCurrentLiabilities', 'otherLiabilities',
#        'capitalLeaseObligations', 'totalLiabilities', 'preferredStock',
#        'commonStock', 'retainedEarnings',
#        'accumulatedOtherComprehensiveIncomeLoss',
#        'othertotalStockholdersEquity', 'totalStockholdersEquity',
#        'totalEquity', 'totalLiabilitiesAndStockholdersEquity',
#        'minorityInterest', 'totalLiabilitiesAndTotalEquity',
#        'totalInvestments', 'totalDebt', 'netDebt', 'link', 'finalLink'],
#       dtype='object')

# %%
import pandas as pd

# List of NASDAQ 100 companies (only symbols are needed for API requests)
nasdaq_100_companies = [
    "AAPL", "MSFT", "AMZN", "NVDA", "GOOGL", "META", "TSLA", "AVGO", "PEP", "COST",
    "ADBE", "CSCO", "TXN", "CMCSA", "NFLX", "AMD", "INTC", "CHTR", "QCOM", "PYPL",
    "SBUX", "ISRG", "BKNG", "GILD", "REGN", "ADI", "TEAM", "DOCU", "ZM", "AMGN",
    "ILMN", "CSX", "MAR", "CTAS", "DXCM", "WDAY", "MNST", "NXPI", "LULU", "EBAY",
    "ORLY", "MELI", "KDP", "ROST", "MCHP", "PCAR", "PANW", "CDNS", "VRTX", "LRCX",
    "KLAC", "ADP", "BIIB", "AMAT", "SNPS", "XLNX", "IDXX", "SPLK", "ALGN", "HOLX",
    "CDNS", "ILMN", "ADSK", "SGEN", "ZBRA", "NTES", "DOCU", "FTNT", "VRSK", "TMUS",
    "CHTR", "CTSH", "XEL", "LBTYA", "TTWO", "EXPE", "EA", "LUMN", "SWKS", "MTCH",
    "MRNA", "OKTA", "ZM", "CMG", "BMRN", "SNOW", "ODFL", "DDOG", "TTD", "PDD",
    "CSGP", "MRVL", "ZS", "CRWD", "EPAM", "PAYX", "FAST", "CERN", "SIRI", "ATUS",
    "NTAP"
]

# Initialize an empty DataFrame
df = pd.DataFrame()

# API key for Financial Modeling Prep
api_key = "qVXvjPhg98aEFqlvCHfmX1lBWWoXbYF4"

# Fetch data for each company and concatenate into the main DataFrame
for symbol in nasdaq_100_companies:
    url = f"https://financialmodelingprep.com/api/v3/income-statement/{'AAPL'}?period=annual&apikey=qVXvjPhg98aEFqlvCHfmX1lBWWoXbYF4"
    try:
        data = get_jsonparsed_data(url)
        if isinstance(data, list) and data:
            df_temp = pd.DataFrame(data)
            df_temp['symbol'] = symbol
            df = pd.concat([df, df_temp], ignore_index=True)
        else:
            print(f"No data returned for {symbol}")
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")

# Set the 'date' column as the index
if not df.empty:
    df.set_index('date', inplace=True)

# Display the DataFrame
print(df)
# Out:
# No data returned for AAPL
# No data returned for MSFT
# No data returned for AMZN
# No data returned for NVDA
# No data returned for GOOGL
# No data returned for META
# No data returned for TSLA
# No data returned for AVGO
# No data returned for PEP
# No data returned for COST
# No data returned for ADBE
# No data returned for CSCO
# No data returned for TXN
# No data returned for CMCSA
# No data returned for NFLX
# No data returned for AMD
# No data returned for INTC
# No data returned for CHTR
# No data returned for QCOM
# No data returned for PYPL
# No data returned for SBUX
# No data returned for ISRG
# No data returned for BKNG
# No data returned for GILD
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-d04c41542856> in <cell line: 25>()
#      26     url = f"https://financialmodelingprep.com/api/v3/income-statement/{'AAPL'}?period=annual&apikey=qVXvjPhg98aEFqlvCHfmX1lBWWoXbYF4"
#      27     try:
# ---> 28         data = get_jsonparsed_data(url)
#      29         if isinstance(data, list) and data:
#      30             df_temp = pd.DataFrame(data)
#
# <ipython-input-11-747b6988eed1> in get_jsonparsed_data(url)
#      19 # Define a function to get JSON data from the API
#      20 def get_jsonparsed_data(url):
# ---> 21     response = requests.get(url)
#      22     return response.json()
#      23
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466             # Trigger any extra validation we need to do.
#     467             try:
# --> 468                 self._validate_conn(conn)
#     469             except (SocketTimeout, BaseSSLError) as e:
#     470                 self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1095         # Force connect early to allow us to validate the connection.
#    1096         if conn.is_closed:
# -> 1097             conn.connect()
#    1098
#    1099         if not conn.is_verified:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in connect(self)
#     640             )
#     641
# --> 642         sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643             sock=sock,
#     644             cert_reqs=self.cert_reqs,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     781             server_hostname = normalized
#     782
# --> 783     ssl_sock = ssl_wrap_socket(
#     784         sock=sock,
#     785         keyfile=key_file,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     469         pass
#     470
# --> 471     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     472     return ssl_sock
#     473
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     513         return SSLTransport(sock, ssl_context, server_hostname)
#     514
# --> 515     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# /usr/lib/python3.10/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511         # SSLSocket class handles server_hostname encoding before it calls
#     512         # ctx._wrap_socket()
# --> 513         return self.sslsocket_class._create(
#     514             sock=sock,
#     515             server_side=server_side,
#
# /usr/lib/python3.10/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1098                         # non-blocking
#    1099                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1100                     self.do_handshake()
#    1101             except (OSError, ValueError):
#    1102                 self.close()
#
# /usr/lib/python3.10/ssl.py in do_handshake(self, block)
#    1369             if timeout == 0.0 and block:
#    1370                 self.settimeout(None)
# -> 1371             self._sslobj.do_handshake()
#    1372         finally:
#    1373             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
df1
# Out:
#            symbol reportedCurrency         cik fillingDate  \
# date
# 2023-09-30   AAPL              USD  0000320193  2023-11-03
# 2022-09-24   AAPL              USD  0000320193  2022-10-28
# 2021-09-25   AAPL              USD  0000320193  2021-10-29
# 2020-09-26   AAPL              USD  0000320193  2020-10-30
# 2019-09-28   AAPL              USD  0000320193  2019-10-31
#
#                    acceptedDate calendarYear period       revenue  \
# date
# 2023-09-30  2023-11-02 18:08:27         2023     FY  383285000000
# 2022-09-24  2022-10-27 18:01:14         2022     FY  394328000000
# 2021-09-25  2021-10-28 18:04:28         2021     FY  365817000000
# 2020-09-26  2020-10-29 18:06:25         2020     FY  274515000000
# 2019-09-28  2019-10-30 18:12:36         2019     FY  260174000000
#
#             costOfRevenue   grossProfit  ...  incomeBeforeTaxRatio  \
# date                                     ...
# 2023-09-30   214137000000  169148000000  ...              0.296740
# 2022-09-24   223546000000  170782000000  ...              0.302040
# 2021-09-25   212981000000  152836000000  ...              0.298529
# 2020-09-26   169559000000  104956000000  ...              0.244398
# 2019-09-28   161782000000   98392000000  ...              0.252666
#
#             incomeTaxExpense    netIncome  netIncomeRatio   eps  epsdiluted  \
# date
# 2023-09-30       16741000000  96995000000        0.253062  6.16        6.13
# 2022-09-24       19300000000  99803000000        0.253096  6.15        6.11
# 2021-09-25       14527000000  94680000000        0.258818  5.67        5.61
# 2020-09-26        9680000000  57411000000        0.209136  3.31        3.28
# 2019-09-28       10481000000  55256000000        0.212381  2.99        2.97
#
#             weightedAverageShsOut  weightedAverageShsOutDil  \
# date
# 2023-09-30            15744231000               15812547000
# 2022-09-24            16215963000               16325819000
# 2021-09-25            16701272000               16864919000
# 2020-09-26            17352119000               17528214000
# 2019-09-28            18471336000               18595652000
#
#                                                          link  \
# date
# 2023-09-30  https://www.sec.gov/Archives/edgar/data/320193...
# 2022-09-24  https://www.sec.gov/Archives/edgar/data/320193...
# 2021-09-25  https://www.sec.gov/Archives/edgar/data/320193...
# 2020-09-26  https://www.sec.gov/Archives/edgar/data/320193...
# 2019-09-28  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                                     finalLink
# date
# 2023-09-30  https://www.sec.gov/Archives/edgar/data/320193...
# 2022-09-24  https://www.sec.gov/Archives/edgar/data/320193...
# 2021-09-25  https://www.sec.gov/Archives/edgar/data/320193...
# 2020-09-26  https://www.sec.gov/Archives/edgar/data/320193...
# 2019-09-28  https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 37 columns]
